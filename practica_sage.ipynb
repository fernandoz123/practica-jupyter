# %%
var('x')
solve(50*x^5-12*x^4-15*x^3-18*x^2-20*x-250==0,x)
# Out:
# [0 == 50*x^5 - 12*x^4 - 15*x^3 - 18*x^2 - 20*x - 250]

# %%
##resolución de un sistema lineal
var('x,y,z')
solve([x-y+2*z==4,2*x+y-3*z==-2,4*x+y+z==6],x,y,z)
# Out:
# [[x == (8/7), y == 0, z == (10/7)]]

# %%
f(x) = (x^3+x^2+x)/(x^2-x-2)
p1(x) = x^3+x^2+x
p2(x) = x^2-x-2
p3(x) = p1.maxima_methods().divide(p2)[0]
p3

pf = plot(f(x), xmin = -8, xmax = 8, ymin = -20, ymax = 20, color = 'green', detect_poles = True, thickness = 1.5)
pp3 = plot(p3(x), xmin = -8, xmax = 8, ymin = -20, ymax = 20, color = 'red', linestyle = '--', legend_label = "Slant Asymptote")
pp3.set_legend_options(handlelength = 2)
v1 = line([(2, -30),(2,30)], color = 'black', linestyle = '--')
v2 = line([(-1, -30),(-1,30)], color = 'black', linestyle = '--')
r = pf+pp3+v1+v2

r.show()
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
var('a,b,c,d')
solve([4*a-b-11*c+3*d==-4,4*a+3*b+c-d==-5,a-2*b-8*c+3*d==-2,4*a-b-11*c==1],a,b,c,d)
# Out:
# []

# %%
m=x^4+3*x^3-2*x^2+9
m.plot(-3,2,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
l=(m==0)
l.find_root(-5,-3)
# Out:
# -3.357905025656101

# %%
A=matrix([[1,1,-1],[4,-1,5],[6,1,3]])
A.rank()
# Out:
# 2

# %%
A.right_kernel() ##vector generador del espacio nulo de la matriz A
##gen{[4,-9,-5]}
##dim(NA)=1
# Out:
# Free module of degree 3 and rank 1 over Integer Ring
# Echelon basis matrix:
# [ 4 -9 -5]

# %%
A.image()  ##vectores generadores del espacio imagen de A
##gen{[1 1 -1],[0 5 -9]} dim(imA)=2
# Out:
# Free module of degree 3 and rank 2 over Integer Ring
# Echelon basis matrix:
# [ 1  1 -1]
# [ 0  5 -9]

# %%
B=matrix([[1,1,-1],[4,-1,5],[6,1,3],[7,4,20]])
B.rank() #matriz aumentada
# Out:
# 3

# %%
m.derivative()
# Out:
# 4*x^3 + 9*x^2 - 4*x

# %%
m.integral(x)
# Out:
# 1/5*x^5 + 3/4*x^4 - 2/3*x^3 + 9*x

# %%
m.subs(x=2)
# Out:
# 41

# %%
limit(f,x=2,dir='plus')
# Out:
# x |--> +Infinity

# %%
limit(f,x=2,dir="minus")
# Out:
# x |--> -Infinity

# %%
c=matrix([[1,-1,5],[3,2,0],[-2,1,7]])
c.image()
# Out:
# Free module of degree 3 and rank 3 over Integer Ring
# Echelon basis matrix:
# [ 1  0 58]
# [ 0  1 53]
# [ 0  0 70]

# %%
var('z')
solve(1+z+z^2==0,z)
# Out:
# [z == -1/2*I*sqrt(3) - 1/2, z == 1/2*I*sqrt(3) - 1/2]

# %%
var('n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-686fd9a1bea6> in <module>()
#       1 var('n')
#       2 z=(Integer(1)+(pi**(Integer(1)/Integer(2)))**(Integer(1)/Integer(2)))**(Integer(1)/Integer(2))
# ----> 3 num(z)
#
# NameError: name 'num' is not defined
